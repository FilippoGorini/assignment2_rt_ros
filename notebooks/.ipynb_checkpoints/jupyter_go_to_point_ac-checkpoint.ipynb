# %% [markdown]
# ## Imports

# %%
import rospy
import actionlib
from nav_msgs.msg import Odometry
from assignment_2_2024.msg import PlanningAction, PlanningGoal
from assignment2_rt_ros.msg import RobotState, Target
import sys
import select
import ipywidgets as widgets
from IPython.display import display, clear_output

# %% [markdown]
# ## Odometry Callback

# %%
def odom_callback(msg):
    robot_state = RobotState()
    robot_state.x        = latest_x
    robot_state.y        = latest_y
    robot_state.vel_x    = msg.twist.twist.linear.x
    robot_state.ang_vel_z= msg.twist.twist.angular.z
    pub_state.publish(robot_state)

# %% [markdown]
# ## ROS initialization and client/pub/sub declarations

# %%
rospy.init_node('jupyter_go_to_point')

client = actionlib.SimpleActionClient('/reaching_goal', PlanningAction)
print("Waiting for action server...")
client.wait_for_server()
print("Connected!")

pub_state  = rospy.Publisher('/robot_state', RobotState, queue_size=10)
pub_target = rospy.Publisher('/last_target', Target,    queue_size=10)
sub_odom = rospy.Subscriber('/odom', Odometry, odom_callback)

latest_x = 0.0
latest_y = 0.0
# Out:
# Waiting for action server...
# Connected!

# %% [markdown]
# ## UI initialization

# %%
# Inputs & Buttons
x_input       = widgets.FloatText(description='Target x:', value=0.0)
y_input       = widgets.FloatText(description='Target y:', value=0.0)
send_button   = widgets.Button(description='Send Goal', button_style='success')
cancel_button = widgets.Button(description='Cancel Goal', button_style='warning')

# Info displays
status_out  = widgets.Output()

# %% [markdown]
# ## Buttons callbacks

# %%
def on_send_clicked(_):
    with status_out:
        clear_output()
        x = x_input.value
        y = y_input.value
        # publish last_target
        pub_target.publish(Target(x, y))
        # build & send PlanningGoal
        goal = PlanningGoal()
        goal.target_pose.pose.position.x = x
        goal.target_pose.pose.position.y = y
        client.send_goal(goal)
        print(f"Goal sent → ({x:.2f}, {y:.2f}).")
        
# Link on_click property to callback
send_button.on_click(on_send_clicked)

def on_cancel_clicked(_):
    with status_out:
        clear_output()
        state = client.get_state()
        if state in [actionlib.GoalStatus.PENDING, actionlib.GoalStatus.ACTIVE]:
            client.cancel_goal()
            print("Goal canceled.")
        else:
            print("No active goal to cancel.")
        
# Link on_click property to callback
cancel_button.on_click(on_cancel_clicked)

# %% [markdown]
# ## Display UI

# %%
controls = widgets.HBox([x_input, y_input, send_button, cancel_button])
display(controls)
display(status_out)
# Out:
# HBox(children=(FloatText(value=0.0, description='Target x:'), FloatText(value=0.0, description='Target y:'), B…
# Output()
